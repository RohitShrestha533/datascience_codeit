# %% [markdown]
# # Reshaping and indexing

# %%
import numpy as np

# %%
arr = np.array((range(5,14),range(6,15),range(7,16),range(8,17),))
arr
# Out:
# array([[ 5,  6,  7,  8,  9, 10, 11, 12, 13],
#        [ 6,  7,  8,  9, 10, 11, 12, 13, 14],
#        [ 7,  8,  9, 10, 11, 12, 13, 14, 15],
#        [ 8,  9, 10, 11, 12, 13, 14, 15, 16]])

# %%
np.shape(arr)
# Out:
# (4, 9)

# %%
np.size(arr)
# Out:
# 36

# %%
# size should be same for reshape where we change the shape

# %%
arr.reshape(9,4)
# Out:
# array([[ 5,  6,  7,  8],
#        [ 9, 10, 11, 12],
#        [13,  6,  7,  8],
#        [ 9, 10, 11, 12],
#        [13, 14,  7,  8],
#        [ 9, 10, 11, 12],
#        [13, 14, 15,  8],
#        [ 9, 10, 11, 12],
#        [13, 14, 15, 16]])

# %%
arr.reshape(3,12)
# Out:
# array([[ 5,  6,  7,  8,  9, 10, 11, 12, 13,  6,  7,  8],
#        [ 9, 10, 11, 12, 13, 14,  7,  8,  9, 10, 11, 12],
#        [13, 14, 15,  8,  9, 10, 11, 12, 13, 14, 15, 16]])

# %%
arr.reshape(1,36)
# Out:
# array([[ 5,  6,  7,  8,  9, 10, 11, 12, 13,  6,  7,  8,  9, 10, 11, 12,
#         13, 14,  7,  8,  9, 10, 11, 12, 13, 14, 15,  8,  9, 10, 11, 12,
#         13, 14, 15, 16]])

# %%
arr.reshape(36,1)
# Out:
# array([[ 5],
#        [ 6],
#        [ 7],
#        [ 8],
#        [ 9],
#        [10],
#        [11],
#        [12],
#        [13],
#        [ 6],
#        [ 7],
#        [ 8],
#        [ 9],
#        [10],
#        [11],
#        [12],
#        [13],
#        [14],
#        [ 7],
#        [ 8],
#        [ 9],
#        [10],
#        [11],
#        [12],
#        [13],
#        [14],
#        [15],
#        [ 8],
#        [ 9],
#        [10],
#        [11],
#        [12],
#        [13],
#        [14],
#        [15],
#        [16]])

# %%
a = np.array(range(1,7))
a
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
a[4]
# Out:
# np.int64(5)

# %%
a[-1]
# Out:
# np.int64(6)

# %%
a[:-1]
# Out:
# array([1, 2, 3, 4, 5])

# %%
arr
# Out:
# array([[ 5,  6,  7,  8,  9, 10, 11, 12, 13],
#        [ 6,  7,  8,  9, 10, 11, 12, 13, 14],
#        [ 7,  8,  9, 10, 11, 12, 13, 14, 15],
#        [ 8,  9, 10, 11, 12, 13, 14, 15, 16]])

# %%
arr[0,2]
#  this serach for item on position 0,2
# Out:
# np.int64(9)

# %%
arr[[0,2]] 
# this serach for row  fo 0 and 2
# Out:
# array([[ 5,  6,  7,  8,  9, 10, 11, 12, 13],
#        [ 7,  8,  9, 10, 11, 12, 13, 14, 15]])

# %%
abc =np.array([[[ 5,  6,  7,  8,  9, 10, 11, 12, 13],[ 5,  6,  7,  8,  9, 10, 11, 12, 13]],
       [[ 6,  7,  8,  9, 10, 11, 12, 13, 14],[ 5,  6,  7,  8,  9, 10, 11, 12, 13]],
       [[ 7,  8,  9, 10, 11, 12, 13, 14, 15],[ 5,  6,  7,  8,  9, 10, 11, 12, 13]],
       [[ 8,  9, 10, 11, 12, 13, 14, 15, 16],[ 5,  6,  7,  8,  9, 10, 11, 12, 13]]])

# %%
np.shape(arr)
# Out:
# (4, 9)

# %%
np.shape(abc)
# Out:
# (4, 2, 9)

# %%
arr[0:3]
# Out:
# array([[ 5,  6,  7,  8,  9, 10, 11, 12, 13],
#        [ 6,  7,  8,  9, 10, 11, 12, 13, 14],
#        [ 7,  8,  9, 10, 11, 12, 13, 14, 15]])

# %%
arr[:-1]
# Out:
# array([[ 5,  6,  7,  8,  9, 10, 11, 12, 13],
#        [ 6,  7,  8,  9, 10, 11, 12, 13, 14],
#        [ 7,  8,  9, 10, 11, 12, 13, 14, 15]])

# %%
arr[-1:]
# Out:
# array([[ 8,  9, 10, 11, 12, 13, 14, 15, 16]])

# %%
arr[::-1]
# Out:
# array([[ 8,  9, 10, 11, 12, 13, 14, 15, 16],
#        [ 7,  8,  9, 10, 11, 12, 13, 14, 15],
#        [ 6,  7,  8,  9, 10, 11, 12, 13, 14],
#        [ 5,  6,  7,  8,  9, 10, 11, 12, 13]])

# %%
arr[-1::]
# Out:
# array([[ 8,  9, 10, 11, 12, 13, 14, 15, 16]])

# %%
arr
# Out:
# array([[ 5,  6,  7,  8,  9, 10, 11, 12, 13],
#        [ 6,  7,  8,  9, 10, 11, 12, 13, 14],
#        [ 7,  8,  9, 10, 11, 12, 13, 14, 15],
#        [ 8,  9, 10, 11, 12, 13, 14, 15, 16]])

# %%
arr[0:4:2] 
# this returns the row from 0 to 4  at leaving 1 row
# Out:
# array([[ 5,  6,  7,  8,  9, 10, 11, 12, 13],
#        [ 7,  8,  9, 10, 11, 12, 13, 14, 15]])

# %%
arr[3]
# Out:
# array([ 8,  9, 10, 11, 12, 13, 14, 15, 16])

# %%
arr[[1,3]]
# Out:
# array([[ 6,  7,  8,  9, 10, 11, 12, 13, 14],
#        [ 8,  9, 10, 11, 12, 13, 14, 15, 16]])

# %%
arr
# Out:
# array([[ 5,  6,  7,  8,  9, 10, 11, 12, 13],
#        [ 6,  7,  8,  9, 10, 11, 12, 13, 14],
#        [ 7,  8,  9, 10, 11, 12, 13, 14, 15],
#        [ 8,  9, 10, 11, 12, 13, 14, 15, 16]])

# %%
arr[[1,1],[2,2]]
# Out:
# array([8, 8])

# %%
arr[[2,1],[3,2]]
# Out:
# array([10,  8])

# %%
arr[arr%2==0]
# Out:
# array([ 6,  8, 10, 12,  6,  8, 10, 12, 14,  8, 10, 12, 14,  8, 10, 12, 14,
#        16])

# %%
x = np.array((5*np.arange(1,6),6*np.arange(1,6),7*np.arange(1,6),8*np.arange(1,6),9*np.arange(1,6),))
x
# Out:
# array([[ 5, 10, 15, 20, 25],
#        [ 6, 12, 18, 24, 30],
#        [ 7, 14, 21, 28, 35],
#        [ 8, 16, 24, 32, 40],
#        [ 9, 18, 27, 36, 45]])

# %%
x[x%7==0]
# Out:
# array([ 7, 14, 21, 28, 35])

# %%
ab = np.array((range(1,3),range(2,4),range(3,5)))
ab
# Out:
# array([[1, 2],
#        [2, 3],
#        [3, 4]])

# %%
ab * 6
# Out:
# array([[ 6, 12],
#        [12, 18],
#        [18, 24]])

# %%
p = np.array((range(4,6),range(2,4),range(3,5)))
p
# Out:
# array([[4, 5],
#        [2, 3],
#        [3, 4]])

# %%
ab * p
# Out:
# array([[ 4, 10],
#        [ 4,  9],
#        [ 9, 16]])

# %%
q = np.array([5,6])
q
# Out:
# array([5, 6])

# %%
p + q
# Out:
# array([[ 9, 11],
#        [ 7,  9],
#        [ 8, 10]])

# %%
ab
# Out:
# array([[1, 2],
#        [2, 3],
#        [3, 4]])

# %%
ab +q
# Out:
# array([[ 6,  8],
#        [ 7,  9],
#        [ 8, 10]])
