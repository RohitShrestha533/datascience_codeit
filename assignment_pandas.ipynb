# %%
import pandas as pd

# %%
a = pd.Series(range(10,51,10))
a
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
data = ['Chitwan','Kathmandu','Pokhara']
label = [10,15,9]
da = pd.Series(data,index=label)
da
# Out:
# 10      Chitwan
# 15    Kathmandu
# 9       Pokhara
# dtype: str

# %%
a.max()
# Out:
# np.int64(50)

# %%
a.min()
# Out:
# np.int64(10)

# %%
a.mean()
# Out:
# np.float64(30.0)

# %%
a.sum()
# Out:
# np.int64(150)

# %%
marks = [85,90,78,88]
sub = ['Math','Science','English','Nepali']
grade = pd.Series(sub,index=marks)

# %%
df = pd.DataFrame({
    'Subject':sub,
    'Marks':marks
})

# %%
df[df['Subject'].isin(['Math','English'])]
# Out:
#    Subject  Marks
# 0     Math     85
# 2  English     78

# %%
df['Marks']+5
# Out:
# 0    90
# 1    95
# 2    83
# 3    93
# Name: Marks, dtype: int64

# %%
df['Marks']*2
# Out:
# 0    170
# 1    180
# 2    156
# 3    176
# Name: Marks, dtype: int64

# %%
lsi=["Apple","Banana","Orange","Mango","Grapes"]
lis_series = pd.Series(lsi)
lis_series
# Out:
# 0     Apple
# 1    Banana
# 2    Orange
# 3     Mango
# 4    Grapes
# dtype: str

# %%
dic ={
    "Nepal":300,
    "India":1400,
    "China":1450
}
pd.Series(dic)
# Out:
# Nepal     300
# India    1400
# China    1450
# dtype: int64

# %%
| Name    | Age | City      |
| ------- | --- | --------- |
| Alice   | 25  | Kathmandu |
| Bob     | 30  | Pokhara   |
| Charlie | 28  | Lalitpur  |
| David   | 35  | Butwal    |

# %%
name =['Alice','Bob','Charlie','David']
Age =[25,30,28,35]
City =['Kathmandu','Pokhara','Lalitpur','Chitwan']

dataf = pd.DataFrame(
    {
        'Name':name,
        'Age':Age,
        'City':City
    }
)
dataf
# Out:
#       Name  Age       City
# 0    Alice   25  Kathmandu
# 1      Bob   30    Pokhara
# 2  Charlie   28   Lalitpur
# 3    David   35    Chitwan

# %%
dataf.head(2)
# Out:
#     Name  Age       City
# 0  Alice   25  Kathmandu
# 1    Bob   30    Pokhara

# %%
dataf.tail(2)
# Out:
#       Name  Age      City
# 2  Charlie   28  Lalitpur
# 3    David   35   Chitwan

# %%
dataf.shape
# Out:
# (4, 3)

# %%
dataf.size
# Out:
# 12

# %%
dataf.columns
# Out:
# Index(['Name', 'Age', 'City'], dtype='str')

# %%
dataf.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
type(dataf)
# Out:
# pandas.DataFrame

# %%
dataf.dtypes
# Out:
# Name      str
# Age     int64
# City      str
# dtype: object

# %%
dataf
# Out:
#       Name  Age       City
# 0    Alice   25  Kathmandu
# 1      Bob   30    Pokhara
# 2  Charlie   28   Lalitpur
# 3    David   35    Chitwan

# %%
dataf['Name']
# Out:
# 0      Alice
# 1        Bob
# 2    Charlie
# 3      David
# Name: Name, dtype: str

# %%
dataf.columns
# Out:
# Index(['Name', 'Age', 'City'], dtype='str')

# %%
dataf[['Name','Age']]
# Out:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   28
# 3    David   35

# %%
dataf.loc[0:0,::]
# Out:
#     Name  Age       City
# 0  Alice   25  Kathmandu

# %%
dataf.iloc[1:2,::]
# Out:
#   Name  Age     City
# 1  Bob   30  Pokhara

# %%
salary=[50000,
60000,
55000,
70000]
dataf
# Out:
#       Name  Age       City
# 0    Alice   25  Kathmandu
# 1      Bob   30    Pokhara
# 2  Charlie   28   Lalitpur
# 3    David   35    Chitwan

# %%
dataf['Salary']=salary
dataf
# Out:
#       Name  Age       City  Salary
# 0    Alice   25  Kathmandu   50000
# 1      Bob   30    Pokhara   60000
# 2  Charlie   28   Lalitpur   55000
# 3    David   35    Chitwan   70000

# %%
dataf['Salary']
# Out:
# 0    50000
# 1    60000
# 2    55000
# 3    70000
# Name: Salary, dtype: int64

# %%
dataf['Bonus']=dataf['Salary']*0.1
dataf
# Out:
#       Name  Age       City  Salary  TotalSalary   Bonus
# 0    Alice   25  Kathmandu   50000      55000.0  5000.0
# 1      Bob   30    Pokhara   60000      66000.0  6000.0
# 2  Charlie   28   Lalitpur   55000      60500.0  5500.0
# 3    David   35    Chitwan   70000      77000.0  7000.0

# %%
dataf['TotalSalary']=dataf['Salary']+dataf['Bonus']
dataf
# Out:
#       Name  Age       City  Salary  TotalSalary   Bonus
# 0    Alice   25  Kathmandu   50000      55000.0  5000.0
# 1      Bob   30    Pokhara   60000      66000.0  6000.0
# 2  Charlie   28   Lalitpur   55000      60500.0  5500.0
# 3    David   35    Chitwan   70000      77000.0  7000.0

# %%
dataf.drop('Bonus',axis=1,inplace=True) # dleete Bonus

# %%
dataf
# Out:
#       Name  Age       City  Salary  TotalSalary
# 0    Alice   25  Kathmandu   50000      55000.0
# 1      Bob   30    Pokhara   60000      66000.0
# 2  Charlie   28   Lalitpur   55000      60500.0
# 3    David   35    Chitwan   70000      77000.0

# %%
dataf['Address']=dataf['City']
dataf
# Out:
#       Name  Age       City  Salary  TotalSalary    Address
# 0    Alice   25  Kathmandu   50000      55000.0  Kathmandu
# 1      Bob   30    Pokhara   60000      66000.0    Pokhara
# 2  Charlie   28   Lalitpur   55000      60500.0   Lalitpur
# 3    David   35    Chitwan   70000      77000.0    Chitwan

# %%
dataf.drop('City',axis=1,inplace=True)

# %%
dataf
# Out:
#       Name  Age  Salary  TotalSalary    Address
# 0    Alice   25   50000      55000.0  Kathmandu
# 1      Bob   30   60000      66000.0    Pokhara
# 2  Charlie   28   55000      60500.0   Lalitpur
# 3    David   35   70000      77000.0    Chitwan

# %%
read = pd.read_csv(r"/Users/rohitshrestha/Projects/datascience_codeit/Pandas_Practice_Dataset.csv")
read
# Out:
#    EmpID     Name Department  Age  Salary  Experience        City
# 0    101    Alice         IT   25   50000           2   Kathmandu
# 1    102      Bob         HR   31   62000           6     Pokhara
# 2    103  Charlie    Finance   29   58000           4    Lalitpur
# 3    104    David         IT   35   80000          10   Bhaktapur
# 4    105      Eva  Marketing   27   54000           3  Biratnagar
# 5    106    Frank      Sales   40   90000          15      Butwal
# 6    107    Grace         IT   24   48000           1      Dharan
# 7    108    Helen    Finance   33   70000           8     Chitwan
# 8    109      Ian         HR   28   52000           3   Nepalgunj
# 9    110     Jane  Marketing   30   61000           5    Janakpur

# %%
read.head()
# Out:
#    EmpID     Name Department  Age  Salary  Experience        City
# 0    101    Alice         IT   25   50000           2   Kathmandu
# 1    102      Bob         HR   31   62000           6     Pokhara
# 2    103  Charlie    Finance   29   58000           4    Lalitpur
# 3    104    David         IT   35   80000          10   Bhaktapur
# 4    105      Eva  Marketing   27   54000           3  Biratnagar

# %%
read.tail()
# Out:
#    EmpID   Name Department  Age  Salary  Experience       City
# 5    106  Frank      Sales   40   90000          15     Butwal
# 6    107  Grace         IT   24   48000           1     Dharan
# 7    108  Helen    Finance   33   70000           8    Chitwan
# 8    109    Ian         HR   28   52000           3  Nepalgunj
# 9    110   Jane  Marketing   30   61000           5   Janakpur

# %%
read_json = pd.read_json(r"/Users/rohitshrestha/Projects/datascience_codeit/Pandas_Practice_Dataset.json")
read_json
# Out:
#    EmpID     Name Department  Age  Salary  Experience        City
# 0    101    Alice         IT   25   50000           2   Kathmandu
# 1    102      Bob         HR   31   62000           6     Pokhara
# 2    103  Charlie    Finance   29   58000           4    Lalitpur
# 3    104    David         IT   35   80000          10   Bhaktapur
# 4    105      Eva  Marketing   27   54000           3  Biratnagar
# 5    106    Frank      Sales   40   90000          15      Butwal
# 6    107    Grace         IT   24   48000           1      Dharan
# 7    108    Helen    Finance   33   70000           8     Chitwan
# 8    109      Ian         HR   28   52000           3   Nepalgunj
# 9    110     Jane  Marketing   30   61000           5    Janakpur

# %%
read_json.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   EmpID       10 non-null     int64
#  1   Name        10 non-null     str
#  2   Department  10 non-null     str
#  3   Age         10 non-null     int64
#  4   Salary      10 non-null     int64
#  5   Experience  10 non-null     int64
#  6   City        10 non-null     str
# dtypes: int64(4), str(3)
# memory usage: 692.0 bytes

# %%
read_excel = pd.read_excel(r"/Users/rohitshrestha/Projects/datascience_codeit/Pandas_Practice_Dataset.xlsx")
read_excel
# Out:
#    EmpID     Name Department  Age  Salary  Experience        City
# 0    101    Alice         IT   25   50000           2   Kathmandu
# 1    102      Bob         HR   31   62000           6     Pokhara
# 2    103  Charlie    Finance   29   58000           4    Lalitpur
# 3    104    David         IT   35   80000          10   Bhaktapur
# 4    105      Eva  Marketing   27   54000           3  Biratnagar
# 5    106    Frank      Sales   40   90000          15      Butwal
# 6    107    Grace         IT   24   48000           1      Dharan
# 7    108    Helen    Finance   33   70000           8     Chitwan
# 8    109      Ian         HR   28   52000           3   Nepalgunj
# 9    110     Jane  Marketing   30   61000           5    Janakpur

# %%
read_excel[['Department','Salary']]
# Out:
#   Department  Salary
# 0         IT   50000
# 1         HR   62000
# 2    Finance   58000
# 3         IT   80000
# 4  Marketing   54000
# 5      Sales   90000
# 6         IT   48000
# 7    Finance   70000
# 8         HR   52000
# 9  Marketing   61000

# %%
read_excel[read_excel['Age']>30]
# Out:
#    EmpID   Name Department  Age  Salary  Experience       City
# 1    102    Bob         HR   31   62000           6    Pokhara
# 3    104  David         IT   35   80000          10  Bhaktapur
# 5    106  Frank      Sales   40   90000          15     Butwal
# 7    108  Helen    Finance   33   70000           8    Chitwan

# %%
read[read['Salary']>60000]
# Out:
#    EmpID   Name Department  Age  Salary  Experience       City
# 1    102    Bob         HR   31   62000           6    Pokhara
# 3    104  David         IT   35   80000          10  Bhaktapur
# 5    106  Frank      Sales   40   90000          15     Butwal
# 7    108  Helen    Finance   33   70000           8    Chitwan
# 9    110   Jane  Marketing   30   61000           5   Janakpur

# %%
read[read['Department'].isin(['IT'])]
# Out:
#    EmpID   Name Department  Age  Salary  Experience       City
# 0    101  Alice         IT   25   50000           2  Kathmandu
# 3    104  David         IT   35   80000          10  Bhaktapur
# 6    107  Grace         IT   24   48000           1     Dharan

# %%
read
# Out:
#    EmpID     Name Department  Age  Salary  Experience        City
# 0    101    Alice         IT   25   50000           2   Kathmandu
# 1    102      Bob         HR   31   62000           6     Pokhara
# 2    103  Charlie    Finance   29   58000           4    Lalitpur
# 3    104    David         IT   35   80000          10   Bhaktapur
# 4    105      Eva  Marketing   27   54000           3  Biratnagar
# 5    106    Frank      Sales   40   90000          15      Butwal
# 6    107    Grace         IT   24   48000           1      Dharan
# 7    108    Helen    Finance   33   70000           8     Chitwan
# 8    109      Ian         HR   28   52000           3   Nepalgunj
# 9    110     Jane  Marketing   30   61000           5    Janakpur

# %%
read['Salary'].min()
# Out:
# np.int64(48000)

# %%
read['Salary'].max()
# Out:
# np.int64(90000)

# %%
read['Salary'].mean()
# Out:
# np.float64(62500.0)

# %%
read['Department'].value_counts() # count the value of department
# Out:
# Department
# IT           3
# HR           2
# Finance      2
# Marketing    2
# Sales        1
# Name: count, dtype: int64

# %%
read['Salary'].sort_values()
# Out:
# 6    48000
# 0    50000
# 8    52000
# 4    54000
# 2    58000
# 9    61000
# 1    62000
# 7    70000
# 3    80000
# 5    90000
# Name: Salary, dtype: int64

# %%
read.sort_values(by='Salary', ascending=False)
# Out:
#    EmpID     Name Department  Age  Salary  Experience        City
# 5    106    Frank      Sales   40   90000          15      Butwal
# 3    104    David         IT   35   80000          10   Bhaktapur
# 7    108    Helen    Finance   33   70000           8     Chitwan
# 1    102      Bob         HR   31   62000           6     Pokhara
# 9    110     Jane  Marketing   30   61000           5    Janakpur
# 2    103  Charlie    Finance   29   58000           4    Lalitpur
# 4    105      Eva  Marketing   27   54000           3  Biratnagar
# 8    109      Ian         HR   28   52000           3   Nepalgunj
# 0    101    Alice         IT   25   50000           2   Kathmandu
# 6    107    Grace         IT   24   48000           1      Dharan

# %%
con1 = read['Age']>25
con2 = read['Age']<35
read[con1 & con2]
# Out:
#    EmpID     Name Department  Age  Salary  Experience        City
# 1    102      Bob         HR   31   62000           6     Pokhara
# 2    103  Charlie    Finance   29   58000           4    Lalitpur
# 4    105      Eva  Marketing   27   54000           3  Biratnagar
# 7    108    Helen    Finance   33   70000           8     Chitwan
# 8    109      Ian         HR   28   52000           3   Nepalgunj
# 9    110     Jane  Marketing   30   61000           5    Janakpur

# %%
con3 = read[read['Department'].isin(['IT'])]
con3
# Out:
#    EmpID   Name Department  Age  Salary  Experience       City
# 0    101  Alice         IT   25   50000           2  Kathmandu
# 3    104  David         IT   35   80000          10  Bhaktapur
# 6    107  Grace         IT   24   48000           1     Dharan

# %%
con3[['Name','City']]
# Out:
#     Name       City
# 0  Alice  Kathmandu
# 3  David  Bhaktapur
# 6  Grace     Dharan

# %%
read[read['Salary']==read['Salary'].max()]
# Out:
#    EmpID   Name Department  Age  Salary  Experience    City
# 5    106  Frank      Sales   40   90000          15  Butwal

# %%
read['Tax']=read['Salary']*0.05
read
# Out:
#    EmpID     Name Department  Age  Salary  Experience        City     Tax
# 0    101    Alice         IT   25   50000           2   Kathmandu  2500.0
# 1    102      Bob         HR   31   62000           6     Pokhara  3100.0
# 2    103  Charlie    Finance   29   58000           4    Lalitpur  2900.0
# 3    104    David         IT   35   80000          10   Bhaktapur  4000.0
# 4    105      Eva  Marketing   27   54000           3  Biratnagar  2700.0
# 5    106    Frank      Sales   40   90000          15      Butwal  4500.0
# 6    107    Grace         IT   24   48000           1      Dharan  2400.0
# 7    108    Helen    Finance   33   70000           8     Chitwan  3500.0
# 8    109      Ian         HR   28   52000           3   Nepalgunj  2600.0
# 9    110     Jane  Marketing   30   61000           5    Janakpur  3050.0

# %% [markdown]
# new_employee.csv
# new_employee.xlsx
# new_employee.json

# %%
read.to_csv('new_employee.csv', index=False)

# %%
read.to_json('new_employee.json', index=False)

# %%
read.to_excel('new_employee.xlsx', index=False)

read.to_json(
    "new_employee.json",
    orient="records",
    indent=4
)

# %%
xyz =read_excel.describe()

# %%
xyz
# Out:
#            EmpID        Age        Salary  Experience
# count   10.00000  10.000000     10.000000   10.000000
# mean   105.50000  30.200000  62500.000000    5.700000
# std      3.02765   4.825856  13705.230145    4.270051
# min    101.00000  24.000000  48000.000000    1.000000
# 25%    103.25000  27.250000  52500.000000    3.000000
# 50%    105.50000  29.500000  59500.000000    4.500000
# 75%    107.75000  32.500000  68000.000000    7.500000
# max    110.00000  40.000000  90000.000000   15.000000
