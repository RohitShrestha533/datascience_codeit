# %%
import pandas as pd

# %%
data = pd.read_csv(r'social_media_screentime_mental_health_2026.csv')
data
# Out:
#      participant_id  age             gender          occupation  \
# 0           P300000   33               Male             Student
# 1           P300001   23             Female  Full-time employed
# 2           P300002   56             Female  Full-time employed
# 3           P300003   13               Male             Student
# 4           P300004   36             Female             Student
# ...             ...  ...                ...                 ...
# 6995        P306995   30               Male  Part-time employed
# 6996        P306996   28               Male       Self-employed
# 6997        P306997   26  Prefer not to say          Unemployed
# 6998        P306998   22             Female             Student
# 6999        P306999   29               Male             Student
#
#              region most_used_platform  platforms_used_count  \
# 0     Latin America             TikTok                     8
# 1           Oceania          Instagram                     8
# ...

# %%
data.isna().sum()
# Out:
# participant_id                           0
# age                                      0
# gender                                  70
# occupation                               0
# region                                   0
# most_used_platform                       0
# platforms_used_count                     0
# daily_screen_hours                       0
# daily_notifications                      0
# night_time_use                           0
# minutes_to_first_check_after_waking      0
# primary_purpose                          0
# avg_sleep_hours                        105
# anxiety_score_0to27                      0
# low_mood_score_0to27                     0
# life_satisfaction_1to10                  0
# loneliness_1to10                         0
# self_esteem_1to10                        0
# fomo_1to10                               0
# social_comparison_1to10                  0
# physical_activity_days_per_week          0
# uses_screen_time_limits                  0
# ...

# %%
df=data.groupby(['age','gender','occupation'])['daily_screen_hours'].mean()

# %%
df
# Out:
# age  gender  occupation
# 13   Female  Full-time employed    3.478462
#              Part-time employed    3.220588
#              Retired               3.242857
#              Self-employed         3.547368
#              Student               3.700000
#                                      ...
# 62   Female  Full-time employed    1.800000
#      Male    Full-time employed    2.300000
# 66   Male    Unemployed            3.800000
# 69   Female  Student               2.700000
# 71   Male    Self-employed         2.600000
# Name: daily_screen_hours, Length: 711, dtype: float64

# %%
df=data.groupby(['age','gender','occupation'])['daily_screen_hours'].agg(['min','max','mean'])
df
# Out:
#                                min   max      mean
# age gender occupation
# 13  Female Full-time employed  0.3   9.3  3.478462
#            Part-time employed  0.7   8.0  3.220588
#            Retired             2.3   5.4  3.242857
#            Self-employed       0.7   7.4  3.547368
#            Student             0.3  10.9  3.700000
# ...                            ...   ...       ...
# 62  Female Full-time employed  1.8   1.8  1.800000
#     Male   Full-time employed  2.3   2.3  2.300000
# 66  Male   Unemployed          3.8   3.8  3.800000
# 69  Female Student             2.7   2.7  2.700000
# 71  Male   Self-employed       2.6   2.6  2.600000
#
# [711 rows x 3 columns]

# %% [markdown]
# <h1>Data Visualization</h1>

# %%
# install matplotlib and seaborn

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
data.head(3)
# Out:
#   participant_id  age  gender          occupation         region  \
# 0        P300000   33    Male             Student  Latin America
# 1        P300001   23  Female  Full-time employed        Oceania
# 2        P300002   56  Female  Full-time employed         Africa
#
#   most_used_platform  platforms_used_count  daily_screen_hours  \
# 0             TikTok                     8                 3.2
# 1          Instagram                     8                 4.5
# 2          Instagram                     1                 5.3
#
#    daily_notifications night_time_use  ...  life_satisfaction_1to10  \
# 0                  172          Never  ...                        9
# 1                   38          Often  ...                        7
# 2                   74    Every night  ...                        8
#
#   loneliness_1to10  self_esteem_1to10  fomo_1to10  social_comparison_1to10  \
# 0                6                  4           6                        8
# ...

# %%
sns.barplot(x='gender',y='daily_screen_hours',data=data)
# Out:
# <Axes: xlabel='gender', ylabel='daily_screen_hours'>

# %%
sns.countplot(x='occupation',data=data)
# Out:
# <Axes: xlabel='occupation', ylabel='count'>

# %%
data
# Out:
#      participant_id  age             gender          occupation  \
# 0           P300000   33               Male             Student
# 1           P300001   23             Female  Full-time employed
# 2           P300002   56             Female  Full-time employed
# 3           P300003   13               Male             Student
# 4           P300004   36             Female             Student
# ...             ...  ...                ...                 ...
# 6995        P306995   30               Male  Part-time employed
# 6996        P306996   28               Male       Self-employed
# 6997        P306997   26  Prefer not to say          Unemployed
# 6998        P306998   22             Female             Student
# 6999        P306999   29               Male             Student
#
#              region most_used_platform  platforms_used_count  \
# 0     Latin America             TikTok                     8
# 1           Oceania          Instagram                     8
# ...

# %%
#line chart
sns.lineplot(x='occupation',y='daily_screen_hours',data=data)
# Out:
# <Axes: xlabel='occupation', ylabel='daily_screen_hours'>

# %%
# scatterplot
sns.scatterplot(x='occupation',y='daily_screen_hours',data=data)
# Out:
# <Axes: xlabel='occupation', ylabel='daily_screen_hours'>

# %%
# KDE PLOT  kenral density estimatro
sns.kdeplot(x='daily_screen_hours',data=data)
plt.axvline(data['daily_screen_hours'].mean(),linestyle='--',color='red')
plt.axhline(2.2,linestyle='--',color='yellow')

# %%
plt.axvline(data['daily_screen_hours'].mean(),linestyle='--',color='red')
