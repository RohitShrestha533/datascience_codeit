# %% [markdown]
# # Basic Statistics

# %%
# measure of central tendency(mean, median, mode)
# measure of dispersion(variance, standard deviation)
# probability basic 
# Distribution concept
# Out:
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r'student_dataset.csv')
data
# Out:
#       study_hours  attendance  sleep_hours  internet_usage  \
# 0               7          56            8               7
# 1               4          69            5               3
# 2              11          60            7               6
# 3               8          99            9               8
# 4               5          52            8               6
# ...           ...         ...          ...             ...
# 9995            2          58            9               7
# 9996            7          98            6               9
# 9997           10          44            8               5
# 9998           10          75            7               5
# 9999            2          70            6              11
#
#       assignments_completed  previous_score  exam_score placement_status
# 0                        10              62      100.00           Placed
# 1                         8              56      100.00           Placed
# ...

# %%
data.isna().sum()
# Out:
# study_hours              0
# attendance               0
# sleep_hours              0
# internet_usage           0
# assignments_completed    0
# previous_score           0
# exam_score               0
# placement_status         0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   study_hours            10000 non-null  int64
#  1   attendance             10000 non-null  int64
#  2   sleep_hours            10000 non-null  int64
#  3   internet_usage         10000 non-null  int64
#  4   assignments_completed  10000 non-null  int64
#  5   previous_score         10000 non-null  int64
#  6   exam_score             10000 non-null  float64
#  7   placement_status       10000 non-null  str
# dtypes: float64(1), int64(6), str(1)
# memory usage: 625.1 KB

# %%
data.columns
# Out:
# Index(['study_hours', 'attendance', 'sleep_hours', 'internet_usage',
#        'assignments_completed', 'previous_score', 'exam_score',
#        'placement_status'],
#       dtype='str')

# %%
# measure of central tendency(mean, median, mode)

# %%
data['exam_score'].mean()
# Out:
# np.float64(86.70420700000001)

# %%
data['exam_score'].median()
# Out:
# np.float64(92.12)

# %%
data['exam_score'].mode()
# Out:
# 0    100.0
# Name: exam_score, dtype: float64

# %%
# measure of dispersion(variance, standard deviation)

# %%
data['exam_score'].var()
# Out:
# np.float64(226.75489394054506)

# %%
data['exam_score'].std()
# Out:
# np.float64(15.058382846127436)

# %%
sns.kdeplot(x='exam_score',data=data)
# Out:
# <Axes: xlabel='exam_score', ylabel='Density'>

# %%
sns.boxplot(y='exam_score',data=data)
# Out:
# <Axes: ylabel='exam_score'>

# %%
data['exam_score'].quantile(0.25)
# Out:
# np.float64(76.7275)

# %%
data['exam_score'].quantile(0.5)
# Out:
# np.float64(92.12)

# %%
data['exam_score'].quantile(0.75)
# Out:
# np.float64(100.0)

# %%
data.placement_status.unique()
# Out:
# <StringArray>
# ['Placed', 'Not Placed']
# Length: 2, dtype: str

# %%
data['placement_status'].value_counts()
# Out:
# placement_status
# Placed        8356
# Not Placed    1644
# Name: count, dtype: int64

# %%
data.shape
# Out:
# (10000, 8)

# %%
# placed prob
8356/10000
# Out:
# 0.8356

# %%
1644/10000
# Out:
# 0.1644

# %%
data.loc[500]['placement_status']
# Out:
# 'Placed'

# %%
data.iloc[787]['placement_status']
# Out:
# 'Placed'

# %%
data.loc[7000]['placement_status']
# Out:
# 'Not Placed'
